# %%
import pandas as pd
import numpy as np
import timeit

# %%
df = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7501 non-null   object
#  1   1       5747 non-null   object
#  2   2       4389 non-null   object
#  3   3       3345 non-null   object
#  4   4       2529 non-null   object
#  5   5       1864 non-null   object
#  6   6       1369 non-null   object
#  7   7       981 non-null    object
#  8   8       654 non-null    object
#  9   9       395 non-null    object
#  10  10      256 non-null    object
#  11  11      154 non-null    object
#  12  12      87 non-null     object
#  13  13      47 non-null     object
#  14  14      25 non-null     object
#  15  15      8 non-null      object
#  16  16      4 non-null      object
#  17  17      4 non-null      object
#  18  18      3 non-null      object
#  19  19      1 non-null      object
# dtypes: object(20)
# memory usage: 1.1+ MB

# %%
allTransection = []
datalen = len(df)
totalCol = len(df.columns)

# %%
totalCol
# Out:
# 20

# %%
# making basket
# -------------

# %%
for i in range(0, datalen):
    allTransection.append([str(df.values[i, j]) for j in range(0, totalCol)])

# %%
allTransection
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %%
import fpgrowth as pfp
import timeit

# %%
start = timeit.timeit()

pattern = pfp.find_frequent_patterns( allTransection, 100 )
rules   = pfp.generate_association_rules( pattern, 0.8 ) 

end = timeit.timeit()

# %%
len(pattern)
# Out:
# 376

# %%
print('times for finding patterns & rules: ', end - start)
# Out:
# times for finding patterns & rules:  -0.002574509999988095

# %%
pattern
# Out:
# {('gums',): 101,
#  ('gums', 'nan'): 1329,
#  ('fromage blanc',): 102,
#  ('fromage blanc', 'nan'): 1315,
#  ('tomato sauce',): 106,
#  ('nan', 'tomato sauce'): 1336,
#  ('black tea',): 107,
#  ('black tea', 'nan'): 1373,
#  ('carrots',): 115,
#  ('carrots', 'nan'): 1479,
#  ('light cream',): 117,
#  ('light cream', 'nan'): 1441,
#  ('pasta',): 118,
#  ('nan', 'pasta'): 1765,
#  ('white wine',): 124,
#  ('nan', 'white wine'): 1785,
#  ('mint',): 131,
#  ('mint', 'nan'): 1869,
#  ('protein bar',): 139,
#  ('nan', 'protein bar'): 1881,
#  ('rice',): 141,
#  ('nan', 'rice'): 1785,
#  ('mushroom cream sauce',): 143,
#  ('mushroom cream sauce', 'nan'): 2089,
#  ('parmesan cheese',): 149,
#  ('nan', 'parmesan cheese'): 1936,
#  ('almonds',): 153,
#  ('almonds', 'nan'): 1923,
#  ('meatballs',): 157,
#  ('meatballs', 'nan'): 2195,
#  ('strawberries',): 160,
#  ('nan', 'strawberries'): 2385,
#  ('fresh tuna',): 167,
#  ('fresh tuna', 'nan'): 2111,
#  ('french wine',): 169,
# ...

# %%
for i in rules:
    if rules[i].count(('nan')) == 0:
        print(i, ' => ', rules[i])
# Out:
# ('gums',)  =>  (('nan',), 13.158415841584159)
# ('fromage blanc',)  =>  (('nan',), 12.892156862745098)
# ('tomato sauce',)  =>  (('nan',), 12.60377358490566)
# ('black tea',)  =>  (('nan',), 12.83177570093458)
# ('carrots',)  =>  (('nan',), 12.860869565217392)
# ('light cream',)  =>  (('nan',), 12.316239316239317)
# ('pasta',)  =>  (('nan',), 14.957627118644067)
# ('white wine',)  =>  (('nan',), 14.39516129032258)
# ('mint',)  =>  (('nan',), 14.267175572519085)
# ('protein bar',)  =>  (('nan',), 13.532374100719425)
# ('rice',)  =>  (('nan',), 12.659574468085106)
# ('mushroom cream sauce',)  =>  (('nan',), 14.608391608391608)
# ('parmesan cheese',)  =>  (('nan',), 12.993288590604028)
# ('almonds',)  =>  (('nan',), 12.568627450980392)
# ('meatballs',)  =>  (('nan',), 13.980891719745223)
# ('strawberries',)  =>  (('nan',), 14.90625)
# ('fresh tuna',)  =>  (('nan',), 12.640718562874252)
# ('french wine',)  =>  (('nan',), 12.911242603550296)
# ('oil',)  =>  (('nan',), 13.046242774566474)
# ...
